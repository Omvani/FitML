# %%
calculated_bmi = (
    df["Weight_kg"] /
    ((df["Height_cm"] / 100) ** 2)
)

comparison = pd.DataFrame({
    "Dataset_BMI": df["BMI"],
    "Calculated_BMI": calculated_bmi
})

comparison["Difference"] = (
    comparison["Dataset_BMI"] -
    comparison["Calculated_BMI"]
)

comparison.describe()
# Out:
#        Dataset_BMI  Calculated_BMI   Difference
# count  6000.000000     6000.000000  6000.000000
# mean     26.094300       26.094274     0.000026
# std       4.162643        4.162457     0.029146
# min      12.900000       12.927910    -0.050000
# 25%      23.300000       23.276837    -0.025349
# 50%      26.000000       26.030433     0.000464
# 75%      28.900000       28.940804     0.025483
# max      44.000000       43.950813     0.049997

# %%
plt.figure(figsize=(8, 6))

sns.heatmap(
    correlation,
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Matrix")
plt.show()

# %%
numeric_columns = [
    "Age",
    "Height_cm",
    "Weight_kg",
    "BMI",
    "Daily_Calorie_Requirement"
]

correlation = df[numeric_columns].corr()

print(correlation)
# Out:
#                                 Age  Height_cm  Weight_kg       BMI  \
# Age                        1.000000   0.003546   0.105740  0.109039
# Height_cm                  0.003546   1.000000   0.413814 -0.246448
# Weight_kg                  0.105740   0.413814   1.000000  0.775497
# BMI                        0.109039  -0.246448   0.775497  1.000000
# Daily_Calorie_Requirement -0.252781   0.517498   0.506589  0.178808
#
#                            Daily_Calorie_Requirement
# Age                                        -0.252781
# Height_cm                                   0.517498
# Weight_kg                                   0.506589
# BMI                                         0.178808
# Daily_Calorie_Requirement                   1.000000

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df,
    x="Activity_Level",
    y="Daily_Calorie_Requirement"
)

plt.title("Activity Level vs Daily Calorie Requirement")
plt.xlabel("Activity Level")
plt.ylabel("Daily Calorie Requirement")

plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=df,
    x="BMI",
    y="Daily_Calorie_Requirement"
)

plt.title("BMI vs Daily Calorie Requirement")
plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=df,
    x="Height_cm",
    y="Daily_Calorie_Requirement"
)

plt.title("Height vs Daily Calorie Requirement")
plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=df,
    x="Weight_kg",
    y="Daily_Calorie_Requirement"
)

plt.title("Weight vs Daily Calorie Requirement")
plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=df,
    x="Age",
    y="Daily_Calorie_Requirement"
)

plt.title("Age vs Daily Calorie Requirement")
plt.show()

# %%
plt.figure(figsize=(6, 5))

sns.countplot(
    data=df,
    x="Gender"
)

plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Number of People")
plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.countplot(
    data=df,
    x="Activity_Level"
)

plt.title("Activity Level Distribution")
plt.xlabel("Activity Level")
plt.ylabel("Number of People")
plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.histplot(
    df["Weight_kg"],
    kde=True
)

plt.title("Weight Distribution")
plt.xlabel("Weight (kg)")
plt.ylabel("Number of People")
plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.histplot(
    df["Age"],
    kde=True
)

plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Number of People")
plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.histplot(
    df["Daily_Calorie_Requirement"],
    kde=True
)

plt.title("Distribution of Daily Calorie Requirement")
plt.xlabel("Daily Calorie Requirement")
plt.ylabel("Number of People")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../DataSet/calorie_health/healthy_diet_calorie_intake.csv")
